# %%
from PIL import Image,ImageOps
import cv2

# %%
img1 = Image.open('/content/djsce.jfif')
display(img1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x7FF8425A3F70>

# %%
img2 = ImageOps.grayscale(img1)

# %%
display(img2)
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x7FF8425980A0>

# %%
flip = img1.transpose(Image.FLIP_LEFT_RIGHT)

# %%
display(flip)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FF84256C1F0>

# %%
flip2=img1.transpose(Image.FLIP_TOP_BOTTOM)

# %%
display(flip2)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FF8425A3A60>

# %%
from PIL import Image
im4 = Image.open("/content/djsce.jfif")
im5 = im4.copy()
display(im5)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FF842610EE0>

# %%
width, height = img1.size

left = 5
top = height / 4
right = 164
bottom = 3 * height / 4
im1 = img1.crop((left, top, right, bottom))
im1.show()
# Out:
# <PIL.Image.Image image mode=RGB size=159x98 at 0x7FF841D000A0>

# %%
from PIL import Image
im = Image.new( 'RGB', (250,250), "black") 
pixels = im.load() # creates the pixel map
display(im) # displays the black image
for i in range(im.size[0]):

 for j in range(im.size[1]):
   pixels[i,j] = (i, j, 100)

 
im.show()
im.save('Image6.jpg')
display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7FF841D24610>
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7FF841D24610>
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7FF841D24610>

# %%
img1 = cv2.imread('/content/djsce.jfif')
import matplotlib.pyplot as plt

# %%
imggray = cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(imggray)

# %%
imgrgb = cv2.cvtColor(imggray,cv2.COLOR_GRAY2BGR)

# %%
plt.imshow(imgrgb)
